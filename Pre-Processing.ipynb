# %% [markdown]
# #### Import Libraries

# %%
# Use Kernel "nlp_course_copy" for this notebook
import pandas as pd     # Pandas for dataframes
import re               # Re for regular expressions
import string           # String for string manipulation

from tqdm import tqdm   # Tqdm for progress bar

import nltk             # Python library for NLP
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize.treebank import TreebankWordDetokenizer

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
df = pd.read_csv('(A) Data/Need To Vote/Combined_News Content Title_800 Data.csv')

df.head()
# Out:
#                                            News_Data 1st Annotator  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...      Positive
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...      Positive
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...      Negative
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...      Positive
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...      Negative
#
#   2nd Annotator 3rd Annotator Voting Result Final Take  Labelling
# 0      Positive      Positive      Positive   Positive          1
# 1      Positive      Positive      Positive   Positive          1
# 2      Negative       Neutral      Negative   Negative         -1
# 3      Positive       Neutral      Positive   Positive          1
# 4      Negative       Neutral      Negative   Negative         -1

# %%
df.shape
# Out:
# (832, 7)

# %%
df = df.drop(columns=["1st Annotator", "2nd Annotator", "3rd Annotator", "Voting Result", "Final Take"])

df.head()
# Out:
#                                            News_Data  Labelling
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1

# %%
df.shape
# Out:
# (832, 2)

# %%
# Check For Missing Values
df.isnull().sum()
# Out:
# News_Data    0
# Labelling    0
# dtype: int64

# %% [markdown]
# #### Cleaning Text

# %%
# Cleaning Text
def cleaning_text(text):

    # Remove punctuation, numbers, and special characters
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\\x\S+', ' ', text)
    text = re.sub(r'\\u\S+', ' ', text)

    for sp in string.punctuation:
      text = text.replace(sp, " ")
    text = re.sub(r"\d+","",text)
    text = text.replace('/\s\s+/g', ' ')

    # Remove URL
    text = re.sub(r'((www.\.[^\s]+)|(https?://[^\s]+))', ' ', text)
    text = re.sub(r'http\S+', ' ', text)

    # Remove text that combines the same characters that are repeated consecutively in a text
    text = re.sub(r'(.)\1+', r'\1\1', text)
    text = re.sub(r'\\n', ' ', text)

    # Remove extra white space
    text = text.strip()
    text = re.sub('\s+', ' ', text)

    return text

# Applied to Content Column
df['Cleaned_News-Data'] = df['News_Data'].apply(cleaning_text)

df.head()
# Out:
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data
# 0  Olahraga Pilates Makin Populer Ini Deret Manfa...
# 1  Janice Tjen Luar Biasa Lolos di Nomor Final Ch...
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...
# 4  Cuaca Panas Hujan hingga Banjir Rob Bayangi Se...

# %%
df['Cleaned_News-Data'][250]
# Out:
# 'Potret Politikus PDIP yang Laporkan Hoax Megawati Meninggal'

# %% [markdown]
# #### Case Folding

# %%
# Uppercase to lowercase
def case_folding_text(text):
  return str(text).lower()

df['Cleaned_News-Data'] = df['Cleaned_News-Data'].apply(case_folding_text)
df.head()
# Out:
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data
# 0  olahraga pilates makin populer ini deret manfa...
# 1  janice tjen luar biasa lolos di nomor final ch...
# 2  siapakah pasukan rsf yang diduga bantai ribuan...
# 3  pertamina peduli salurkan bantuan untuk korban...
# 4  cuaca panas hujan hingga banjir rob bayangi se...

# %% [markdown]
# #### Tokenization

# %% [markdown]
# Tokenization is the process of breaking down raw text into smaller units called tokens, such as words, subwords, or characters, to make it understandable for computers in Natural Language Processing (NLP).

# %%
def tokenizing_text(data):
    return nltk.tokenize.word_tokenize(data)

df['Tokenized'] = df['Cleaned_News-Data'].apply(tokenizing_text)
df.head()
# Out:
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data  \
# 0  olahraga pilates makin populer ini deret manfa...
# 1  janice tjen luar biasa lolos di nomor final ch...
# 2  siapakah pasukan rsf yang diduga bantai ribuan...
# 3  pertamina peduli salurkan bantuan untuk korban...
# 4  cuaca panas hujan hingga banjir rob bayangi se...
#
#                                            Tokenized
# 0  [olahraga, pilates, makin, populer, ini, deret...
# 1  [janice, tjen, luar, biasa, lolos, di, nomor, ...
# 2  [siapakah, pasukan, rsf, yang, diduga, bantai,...
# 3  [pertamina, peduli, salurkan, bantuan, untuk, ...
# 4  [cuaca, panas, hujan, hingga, banjir, rob, bay...

# %%
# Normalization

# %% [markdown]
# #### StopWords Removal

# %% [markdown]
# Some words like "the" and "and" appear so frequently, and in so many documents, that we needn't bother counting them. Also, it may make sense to only record the root of a word, say `cat` in place of both `cat` and `cats`. This will shrink our vocab array and improve performance.

# %% [markdown]
# Stop words are common words like "the," "a," and "is" that are removed in Natural Language Processing (NLP) to improve efficiency and accuracy by focusing on more meaningful terms.

# %%
def stopword_text(tokens):
    stopword = stopwords.words('indonesian')
    filtered_tokens = [token for token in tokens if token not in stopword]
    return filtered_tokens

df['Tokenized_Stopword'] = df['Tokenized'].apply(stopword_text)

df.head()
# Out:
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data  \
# 0  olahraga pilates makin populer ini deret manfa...
# 1  janice tjen luar biasa lolos di nomor final ch...
# 2  siapakah pasukan rsf yang diduga bantai ribuan...
# 3  pertamina peduli salurkan bantuan untuk korban...
# 4  cuaca panas hujan hingga banjir rob bayangi se...
#
#                                            Tokenized  \
# 0  [olahraga, pilates, makin, populer, ini, deret...
# 1  [janice, tjen, luar, biasa, lolos, di, nomor, ...
# 2  [siapakah, pasukan, rsf, yang, diduga, bantai,...
# 3  [pertamina, peduli, salurkan, bantuan, untuk, ...
# 4  [cuaca, panas, hujan, hingga, banjir, rob, bay...
#
#                                   Tokenized_Stopword
# 0    [olahraga, pilates, populer, deret, manfaatnya]
# 1  [janice, tjen, lolos, nomor, final, chennai, o...
# 2  [pasukan, rsf, diduga, bantai, ribuan, warga, ...
# 3  [pertamina, peduli, salurkan, bantuan, korban,...
# 4  [cuaca, panas, hujan, banjir, rob, bayangi, wi...

# %% [markdown]
# #### Stemming

# %% [markdown]
# Stemming is an NLP technique that reduces a word to its root or base form, called a "stem," by removing affixes like suffixes.

# %%
def stemming_text(tokens):
    # Stemming Using Sastrawi Liblary
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    stems = [stemmer.stem(token) for token in tokens]
    return stems

tqdm.pandas(desc="Stemming Progress: ")
df['Tokenized_Stopword_Stemmed'] = df['Tokenized_Stopword'].progress_apply(stemming_text)

df.head()
# Out:
# Stemming Progress: 100%|██████████| 832/832 [09:53<00:00,  1.40it/s]
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data  \
# 0  olahraga pilates makin populer ini deret manfa...
# 1  janice tjen luar biasa lolos di nomor final ch...
# 2  siapakah pasukan rsf yang diduga bantai ribuan...
# 3  pertamina peduli salurkan bantuan untuk korban...
# 4  cuaca panas hujan hingga banjir rob bayangi se...
#
#                                            Tokenized  \
# 0  [olahraga, pilates, makin, populer, ini, deret...
# 1  [janice, tjen, luar, biasa, lolos, di, nomor, ...
# 2  [siapakah, pasukan, rsf, yang, diduga, bantai,...
# 3  [pertamina, peduli, salurkan, bantuan, untuk, ...
# 4  [cuaca, panas, hujan, hingga, banjir, rob, bay...
#
#                                   Tokenized_Stopword  \
# 0    [olahraga, pilates, populer, deret, manfaatnya]
# 1  [janice, tjen, lolos, nomor, final, chennai, o...
# 2  [pasukan, rsf, diduga, bantai, ribuan, warga, ...
# 3  [pertamina, peduli, salurkan, bantuan, korban,...
# 4  [cuaca, panas, hujan, banjir, rob, bayangi, wi...
#
#                           Tokenized_Stopword_Stemmed
# 0       [olahraga, pilates, populer, deret, manfaat]
# 1  [janice, tjen, lolos, nomor, final, chennai, o...
# 2  [pasu, rsf, duga, bantai, ribu, warga, sipil, ...
# 3  [pertamina, peduli, salur, bantu, korban, benc...
# 4  [cuaca, panas, hujan, banjir, rob, bayang, wil...

# %% [markdown]
# #### DeTokenized

# %%
def detokenize(tokens):
  return TreebankWordDetokenizer().detokenize(tokens)

df['Detokenized'] = df['Tokenized_Stopword_Stemmed'].apply(detokenize)
df.head()
# Out:
#                                            News_Data  Labelling  \
# 0  Olahraga Pilates Makin Populer, Ini Deret Manf...          1
# 1  Janice Tjen Luar Biasa, Lolos di 2 Nomor Final...          1
# 2  Siapakah Pasukan RSF yang Diduga Bantai Ribuan...         -1
# 3  Pertamina Peduli Salurkan Bantuan untuk Korban...          1
# 4  Cuaca Panas, Hujan hingga Banjir Rob Bayangi S...         -1
#
#                                    Cleaned_News-Data  \
# 0  olahraga pilates makin populer ini deret manfa...
# 1  janice tjen luar biasa lolos di nomor final ch...
# 2  siapakah pasukan rsf yang diduga bantai ribuan...
# 3  pertamina peduli salurkan bantuan untuk korban...
# 4  cuaca panas hujan hingga banjir rob bayangi se...
#
#                                            Tokenized  \
# 0  [olahraga, pilates, makin, populer, ini, deret...
# 1  [janice, tjen, luar, biasa, lolos, di, nomor, ...
# 2  [siapakah, pasukan, rsf, yang, diduga, bantai,...
# 3  [pertamina, peduli, salurkan, bantuan, untuk, ...
# 4  [cuaca, panas, hujan, hingga, banjir, rob, bay...
#
#                                   Tokenized_Stopword  \
# 0    [olahraga, pilates, populer, deret, manfaatnya]
# 1  [janice, tjen, lolos, nomor, final, chennai, o...
# 2  [pasukan, rsf, diduga, bantai, ribuan, warga, ...
# 3  [pertamina, peduli, salurkan, bantuan, korban,...
# 4  [cuaca, panas, hujan, banjir, rob, bayangi, wi...
#
#                           Tokenized_Stopword_Stemmed  \
# 0       [olahraga, pilates, populer, deret, manfaat]
# 1  [janice, tjen, lolos, nomor, final, chennai, o...
# 2  [pasu, rsf, duga, bantai, ribu, warga, sipil, ...
# 3  [pertamina, peduli, salur, bantu, korban, benc...
# 4  [cuaca, panas, hujan, banjir, rob, bayang, wil...
#
#                                          Detokenized
# 0             olahraga pilates populer deret manfaat
# 1         janice tjen lolos nomor final chennai open
# 2        pasu rsf duga bantai ribu warga sipil sudan
# 3  pertamina peduli salur bantu korban bencana su...
# 4        cuaca panas hujan banjir rob bayang wilayah

# %%
output_path = r'(A) Data/PreProcessed_News Content Title_800 Data.csv'
df.to_csv(output_path, index=False)
print(f"Completed PreProcessed data saved to {output_path}")
# Out:
# Completed PreProcessed data saved to (A) Data/PreProcessed_News Content Title_800 Data.csv
